# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
from sklearn.cluster import KMeans

# %%
master_df = pd.read_csv("../output/master_df.csv")
master_df
# Out:
#               distname                      schoolname  flag_nerds  flag_f33  \
# 0             Abington                   Abington High           0         0
# 1             Abington          Abington Middle School           0         0
# 2             Abington     Woodsdale Elementary School           0         0
# 3     Acton-Boxborough  Acton-Boxborough Regional High           0         0
# 4     Acton-Boxborough       Blanchard Memorial School           0         0
# ...                ...                             ...         ...       ...
# 1446         Worcester           Worcester East Middle           0         0
# 1447         Worcester        Worcester Technical High           0         0
# 1448       Worthington                   R. H. Conwell           1         1
# 1449          Wrentham              Charles E Roderick           0         0
# 1450          Wrentham                         Delaney           0         0
#
#       ncesenroll gradespan  pp_stloc_raw_MA  pp_fed_raw_MA  pp_total_raw_MA  \
# 0          545.0     09-12     14880.475672      20.812074     14901.287746
# 1          672.0     05-08     13057.825084      83.417661     13141.242745
# 2          294.0     03-04     13201.700857     499.583587     13701.284443
# 3         1837.0     09-12     14634.333856     191.007988     14825.341844
# 4          464.0     KG-06     16005.357328     289.306328     16294.663656
# ...          ...       ...              ...            ...              ...
# 1446       766.0     07-08     14603.898777     923.333657     15527.232434
# 1447      1426.0     09-12     16973.789244     812.745854     17786.535098
# 1448        74.0     PK-06     16583.928533     219.228195     16803.156728
# 1449       442.0     04-06     16436.024662     279.413743     16715.438405
# 1450       567.0     PK-03     16889.475004     292.720058     17182.195062
#
#       schoolstloc_raw_MA  ...  males_staff  fte_staff student_teacher_ratio  \
# 0           8.052652e+06  ...         27.5       62.4                  14.4
# 1           8.839857e+06  ...         22.7       73.7                  17.6
# 2           3.841768e+06  ...         11.2       39.4                  18.0
# 3           2.676628e+07  ...         23.9      195.0                  14.7
# 4           7.481971e+06  ...          8.6       79.3                  14.3
# ...                  ...  ...          ...        ...                   ...
# 1446        1.110659e+07  ...         37.5       82.0                  12.8
# 1447        2.374180e+07  ...         51.0      176.8                  10.9
# 1448        1.239096e+06  ...         16.3       16.0                  10.6
# 1449        7.210758e+06  ...          5.2       63.0                  12.8
# 1450        8.907978e+06  ...          4.8       96.7                  13.0
#
#      nan_flag     District Name  District Code  salary_totals_teachers  \
# 0       False          Abington        10000.0              11469788.0
# 1       False          Abington        10000.0              11469788.0
# 2       False          Abington        10000.0              11469788.0
# 3       False  Acton-Boxborough      6000000.0              32945978.0
# 4       False  Acton-Boxborough      6000000.0              32945978.0
# ...       ...               ...            ...                     ...
# 1446    False         Worcester      3480000.0             151535395.0
# 1447    False         Worcester      3480000.0             151535395.0
# 1448    False       Worthington      3490000.0                376966.0
# 1449    False          Wrentham      3500000.0               6138763.0
# 1450    False          Wrentham      3500000.0               6138763.0
#
#       avg_salary_teachers  FTE Count  no_salary_flag
# 0                 93861.0      122.2           False
# 1                 93861.0      122.2           False
# 2                 93861.0      122.2           False
# 3                 86677.0      380.1           False
# 4                 86677.0      380.1           False
# ...                   ...        ...             ...
# 1446              80121.0    1,891.3           False
# 1447              80121.0    1,891.3           False
# 1448              53852.0        7.0           False
# 1449              76543.0       80.2           False
# 1450              76543.0       80.2           False
#
# [1451 rows x 74 columns]

# %% [markdown]
# ## 2.1 Cluster Analysis - General Insight Extraction (WIP)
# - format the learnings into more readable / understandable format
# - maybe write one sentence blurbs for each one too
# - need to add more columns for some of the correlation analysis
# - analyze the hierarchal outcome. what were the main groupings?
# - add a paragraph summarizing the learnings in the last section

# %% [markdown]
# ### 2.1.0 Defining KMeans Function

# %%
def kmeans_func(clusters, df):
    # select the columns you want to calculate correlation with
    columns_of_interest = ['avg_score', 'pp_stloc_raw_MA', 'pp_fed_raw_MA', 'pp_total_raw_MA', 'ncesenroll', 'pp_stloc_raw_MA', 'pp_fed_raw_MA','First Language Not English %', 'student_teacher_ratio','High Needs #.1', 'Economically Disadvantaged %', 'African American', 'Asian', 'Hispanic', 'White', 'Native American', 'Native Hawaiian, Pacific Islander', 'avg_salary_teachers', 'student_teacher_ratio']
    
    # calculate the correlations between the selected columns and the test performance column
    filtered_df = df[columns_of_interest]
    filtered_df = filtered_df.dropna()
    
    # standardize the data
    df_standardized = (filtered_df - filtered_df.mean()) / filtered_df.std()
    
    # fit the k-means algorithm on the standardized data
    kmeans = KMeans(n_clusters=clusters, random_state=0).fit(df_standardized)

    # get the cluster labels for each school
    cluster_labels = kmeans.labels_

    # add the cluster labels as a new column to the original dataframe
    filtered_df['cluster'] = cluster_labels

    # calculate the mean values of each feature for each cluster
    cluster_means = filtered_df.groupby('cluster').mean()

    # explanatory analysis
    print(filtered_df['cluster'].value_counts())
    return cluster_means

# %% [markdown]
# ### 2.1.1 All Schools - 2 Clusters

# %%
cluster = kmeans_func(2, master_df)
cluster
# Out:
# 0    1056
# 1     368
# Name: cluster, dtype: int64
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#           avg_score  pp_stloc_raw_MA  pp_fed_raw_MA  pp_total_raw_MA  \
# cluster
# 0        505.810709     16092.865587     359.553151     16452.418738
# 1        490.574457     15700.762622    1182.130496     16882.893117
#
#          ncesenroll  pp_stloc_raw_MA  pp_fed_raw_MA  \
# cluster
# 0        544.175189     16092.865587     359.553151
# 1        600.839674     15700.762622    1182.130496
#
#          First Language Not English %  student_teacher_ratio  High Needs #.1  \
# cluster
# 0                           10.027367              12.883428       34.640814
# 1                           42.368750              13.175669       77.080435
#
#          Economically Disadvantaged %  African American     Asian   Hispanic  \
# cluster
# 0                           19.534564          3.642614  6.647254   7.865720
# 1                           61.147826         15.423098  6.339402  47.889674
#
#              White  Native American  Native Hawaiian, Pacific Islander  \
# cluster
# 0        77.453693         0.223958                           0.091288
# 1        26.211685         0.211413                           0.063315
#
#          avg_salary_teachers  student_teacher_ratio
# cluster
# 0               80575.817235              12.883428
# 1               79830.005435              13.175669

# %% [markdown]
# ### 2.1.2 All Schools - 4 Clusters

# %%
cluster = kmeans_func(4, master_df)
cluster
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 0    611
# 3    439
# 1    318
# 2     56
# Name: cluster, dtype: int64
#           avg_score  pp_stloc_raw_MA  pp_fed_raw_MA  pp_total_raw_MA  \
# cluster
# 0        505.314948     14073.408261     330.232633     14403.640894
# 1        491.154507     14377.055135    1136.446835     15513.501970
# 2        490.384226     28243.183240    1350.024318     29593.207558
# 3        506.313041     18267.818822     400.793977     18668.612799
#
#          ncesenroll  pp_stloc_raw_MA  pp_fed_raw_MA  \
# cluster
# 0        575.711948     14073.408261     330.232633
# 1        626.446541     14377.055135    1136.446835
# 2        325.321429     28243.183240    1350.024318
# 3        516.104784     18267.818822     400.793977
#
#          First Language Not English %  student_teacher_ratio  High Needs #.1  \
# cluster
# 0                            8.617349              14.046481       33.656792
# 1                           43.129560              13.776415       77.201258
# 2                           30.266071               8.515114       69.696429
# 3                           12.540547              11.420046       36.284738
#
#          Economically Disadvantaged %  African American     Asian   Hispanic  \
# cluster
# 0                           19.733224          3.139444  5.844517   7.645499
# 1                           61.645912         14.483962  6.532075  49.038365
# 2                           51.100000         21.857143  5.953571  30.608929
# 3                           19.610251          4.041458  7.678360   8.997494
#
#              White  Native American  Native Hawaiian, Pacific Islander  \
# cluster
# 0        79.421440         0.171522                           0.083961
# 1        25.806289         0.208491                           0.059119
# 2        35.616071         0.348214                           0.083929
# 3        74.509339         0.281777                           0.102278
#
#          avg_salary_teachers  student_teacher_ratio
# cluster
# 0               78581.364975              14.046481
# 1               78251.685535              13.776415
# 2               91113.017857               8.515114
# 3               83065.890661              11.420046

# %% [markdown]
# ### 2.1.3 KMeans - 6 Clusters

# %%
cluster = kmeans_func(6, master_df)
cluster
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 3    512
# 0    297
# 2    206
# 1    193
# 5    165
# 4     51
# Name: cluster, dtype: int64
#           avg_score  pp_stloc_raw_MA  pp_fed_raw_MA  pp_total_raw_MA  \
# cluster
# 0        502.144557     18133.525946     497.777807     18631.303753
# 1        495.717530     14013.493699     799.868954     14813.362653
# 2        513.737985     17356.096828     245.891662     17601.988490
# 3        504.996468     14049.175787     320.266106     14369.441892
# 4        490.640523     28863.441349    1256.464348     30119.905696
# 5        487.552778     14794.640949    1416.895898     16211.536847
#
#          ncesenroll  pp_stloc_raw_MA  pp_fed_raw_MA  \
# cluster
# 0        450.774411     18133.525946     497.777807
# 1        757.259067     14013.493699     799.868954
# 2        640.800971     17356.096828     245.891662
# 3        550.896484     14049.175787     320.266106
# 4        333.764706     28863.441349    1256.464348
# 5        512.975758     14794.640949    1416.895898
#
#          First Language Not English %  student_teacher_ratio  High Needs #.1  \
# cluster
# 0                           10.057239              10.889226       41.396633
# 1                           35.674611              14.315026       66.410363
# 2                           18.323301              13.210680       29.293204
# 3                            5.950977              13.901953       31.851758
# 4                           29.762745               8.426399       69.190196
# 5                           48.296970              13.258788       84.624848
#
#          Economically Disadvantaged %  African American      Asian   Hispanic  \
# cluster
# 0                           26.750168          4.035017   2.747811  10.298316
# 1                           49.126425         16.269430   8.963731  30.948705
# 2                            9.267961          3.844660  19.914563   5.846117
# 3                           18.633984          2.612891   3.502734   6.818164
# 4                           50.354902         23.013725   6.450980  29.556863
# 5                           70.829091         11.396364   3.524242  64.820000
#
#              White  Native American  Native Hawaiian, Pacific Islander  \
# cluster
# 0        78.323569         0.367677                           0.113805
# 1        38.656995         0.249223                           0.101554
# 2        64.951942         0.121359                           0.089320
# 3        83.457617         0.167187                           0.078125
# 4        34.837255         0.350980                           0.080392
# 5        17.133333         0.172727                           0.023030
#
#          avg_salary_teachers  student_teacher_ratio
# cluster
# 0               77655.326599              10.889226
# 1               81099.704663              14.315026
# 2               90495.247573              13.210680
# 3               77995.148438              13.901953
# 4               91843.098039               8.426399
# 5               75697.545455              13.258788

# %% [markdown]
# ## 2.2 Cluster Analysis - High Schools

# %% [markdown]
# ### 2.2.1 High Schools - 2 Clusters

# %%
# filter dataframe to only high schools
df_highschool = master_df.dropna(subset=['gradespan'])
df_highschool = df_highschool[df_highschool['gradespan'].str.contains('09-12') | df_highschool['gradespan'].str.contains('08-12')]

cluster = kmeans_func(2, df_highschool)
cluster
# Out:
# 0    195
# 1     49
# Name: cluster, dtype: int64
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#           avg_score  pp_stloc_raw_MA  pp_fed_raw_MA  pp_total_raw_MA  \
# cluster
# 0        509.070855     16333.328390     302.262886     16635.591276
# 1        492.525510     18626.980473    1056.998984     19683.979457
#
#           ncesenroll  pp_stloc_raw_MA  pp_fed_raw_MA  \
# cluster
# 0         950.394872     16333.328390     302.262886
# 1        1296.734694     18626.980473    1056.998984
#
#          First Language Not English %  student_teacher_ratio  High Needs #.1  \
# cluster
# 0                            8.011795              12.695385       31.102051
# 1                           40.948980              12.024490       68.167347
#
#          Economically Disadvantaged %  African American     Asian   Hispanic  \
# cluster
# 0                           18.462051          3.435897  5.162051   7.966667
# 1                           51.318367         17.832653  5.622449  43.530612
#
#              White  Native American  Native Hawaiian, Pacific Islander  \
# cluster
# 0        80.141538         0.204103                           0.085641
# 1        29.404082         0.371429                           0.132653
#
#          avg_salary_teachers  student_teacher_ratio
# cluster
# 0               80445.692308              12.695385
# 1               85201.265306              12.024490

# %% [markdown]
# ### 2.2.1 High Schools - 4 Clusters

# %%
# filter dataframe to only high schools
df_highschool = master_df.dropna(subset=['gradespan'])
df_highschool = df_highschool[df_highschool['gradespan'].str.contains('09-12') | df_highschool['gradespan'].str.contains('08-12')]

cluster = kmeans_func(4, df_highschool)
cluster
# Out:
# 1    139
# 3     55
# 2     34
# 0     16
# Name: cluster, dtype: int64
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#           avg_score  pp_stloc_raw_MA  pp_fed_raw_MA  pp_total_raw_MA  \
# cluster
# 0        485.568750     19317.042022    1693.807292     21010.849313
# 1        511.732734     15325.351916     214.007540     15539.359456
# 2        496.896078     15025.582995     621.615361     15647.198356
# 3        501.966364     20864.630342     595.478655     21460.108997
#
#           ncesenroll  pp_stloc_raw_MA  pp_fed_raw_MA  \
# cluster
# 0         725.625000     19317.042022    1693.807292
# 1         973.352518     15325.351916     214.007540
# 2        1698.411765     15025.582995     621.615361
# 3         803.909091     20864.630342     595.478655
#
#          First Language Not English %  student_teacher_ratio  High Needs #.1  \
# cluster
# 0                           45.543750              11.393750       79.150000
# 1                            6.702878              13.212230       25.992806
# 2                           40.820588              13.726471       60.852941
# 3                            9.463636              10.532727       44.667273
#
#          Economically Disadvantaged %  African American     Asian   Hispanic  \
# cluster
# 0                           64.650000         23.006250  3.606250  59.375000
# 1                           14.210072          2.957554  5.561151   6.072662
# 2                           44.511765         14.317647  8.926471  36.555882
# 3                           28.940000          5.050909  2.689091  11.809091
#
#              White  Native American  Native Hawaiian, Pacific Islander  \
# cluster
# 0        11.956250         0.193750                           0.068750
# 1        82.479137         0.158273                           0.084892
# 2        36.602941         0.194118                           0.102941
# 3        75.781818         0.478182                           0.123636
#
#          avg_salary_teachers  student_teacher_ratio
# cluster
# 0               88989.062500              11.393750
# 1               81240.510791              13.212230
# 2               79821.911765              13.726471
# 3               80574.018182              10.532727

# %% [markdown]
# ## 2.3 Cluster Analysis - High performing, High income Schools

# %% [markdown]
# ### 2.3.1 High performing, high income schools - 2 clusters

# %%
# filter dataframe to only high performing, high income
score_threshold = master_df['avg_score'].quantile(0.7)
income_threshold = master_df['Economically Disadvantaged %'].quantile(0.3)
filtered_df = master_df[(master_df['avg_score'] >= score_threshold) & (master_df['Economically Disadvantaged %'] <= income_threshold)]

cluster = kmeans_func(2, filtered_df)
cluster
# Out:
# 507.2
# 14.5
# 0    218
# 1    115
# Name: cluster, dtype: int64
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#           avg_score  pp_stloc_raw_MA  pp_fed_raw_MA  pp_total_raw_MA  \
# cluster
# 0        512.871139     14760.886112     216.108584     14976.994696
# 1        515.221522     18046.248995     270.622939     18316.871934
#
#          ncesenroll  pp_stloc_raw_MA  pp_fed_raw_MA  \
# cluster
# 0        637.055046     14760.886112     216.108584
# 1        643.217391     18046.248995     270.622939
#
#          First Language Not English %  student_teacher_ratio  High Needs #.1  \
# cluster
# 0                            5.946330              13.426606       22.665138
# 1                           18.874783              12.700000       28.327826
#
#          Economically Disadvantaged %  African American     Asian  Hispanic  \
# cluster
# 0                            8.189908          1.949541   6.91422  4.032110
# 1                            7.014783          3.880000  21.16087  6.183478
#
#              White  Native American  Native Hawaiian, Pacific Islander  \
# cluster
# 0        83.439450         0.135780                           0.080275
# 1        62.870435         0.111304                           0.073913
#
#          avg_salary_teachers  student_teacher_ratio
# cluster
# 0               82159.559633              13.426606
# 1               91512.008696              12.700000

# %% [markdown]
# ### 2.3.2 - High performing, high income schools - 4 clusters

# %%
# filter dataframe to only high performing, high income
score_threshold = master_df['avg_score'].quantile(0.7)
income_threshold = master_df['Economically Disadvantaged %'].quantile(0.3)
filtered_df = master_df[(master_df['avg_score'] >= score_threshold) & (master_df['Economically Disadvantaged %'] <= income_threshold)]

cluster = kmeans_func(4, filtered_df)
cluster
# Out:
# 1    109
# 0    104
# 3     65
# 2     55
# Name: cluster, dtype: int64
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#           avg_score  pp_stloc_raw_MA  pp_fed_raw_MA  pp_total_raw_MA  \
# cluster
# 0        513.341506     13680.218716     187.258814     13867.477530
# 1        512.170413     15761.107490     261.014972     16022.122462
# 2        514.580303     16065.745152     269.994854     16335.740006
# 3        516.005769     19521.113239     237.816059     19758.929298
#
#          ncesenroll  pp_stloc_raw_MA  pp_fed_raw_MA  \
# cluster
# 0        747.673077     13680.218716     187.258814
# 1        563.449541     15761.107490     261.014972
# 2        633.436364     16065.745152     269.994854
# 3        597.461538     19521.113239     237.816059
#
#          First Language Not English %  student_teacher_ratio  High Needs #.1  \
# cluster
# 0                            7.775962              14.650000       22.228846
# 1                            3.982569              12.102752       23.323853
# 2                           28.081818              13.256364       32.069091
# 3                           10.455385              12.547692       24.320000
#
#          Economically Disadvantaged %  African American      Asian  Hispanic  \
# cluster
# 0                            7.945192          2.825962   8.941346  4.410577
# 1                            8.848624          1.319266   4.419266  3.755963
# 2                            7.796364          3.605455  30.190909  6.496364
# 3                            5.730769          3.618462  13.364615  5.610769
#
#              White  Native American  Native Hawaiian, Pacific Islander  \
# cluster
# 0        79.643269         0.127885                           0.065385
# 1        87.542202         0.151376                           0.109174
# 2        53.645455         0.143636                           0.065455
# 3        71.452308         0.072308                           0.056923
#
#          avg_salary_teachers  student_teacher_ratio
# cluster
# 0               82191.596154              14.650000
# 1               81260.211009              12.102752
# 2               87369.309091              13.256364
# 3               95754.830769              12.547692

# %% [markdown]
# ## 2.4 What type of features do high performing, low income schools have?

# %%
# filter dataframe to only high performing, low income
score_threshold = master_df['avg_score'].quantile(0.7)
income_threshold = master_df['Economically Disadvantaged %'].quantile(0.7)
filtered_df = master_df[(master_df['avg_score'] >= score_threshold) & (master_df['Economically Disadvantaged %'] >= income_threshold)]
filtered_df
# Out:
# 1    2
# 3    1
# 2    1
# 0    1
# Name: cluster, dtype: int64
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#           avg_score  pp_stloc_raw_MA  pp_fed_raw_MA  pp_total_raw_MA  \
# cluster
# 0        509.133333     16125.763319    1887.108685     18012.872004
# 1        507.850000     20212.026385     395.637635     20607.664020
# 2        516.433333     13392.063357     871.505310     14263.568667
# 3        508.733333     16184.207293    1921.303664     18105.510957
#
#          ncesenroll  pp_stloc_raw_MA  pp_fed_raw_MA  \
# cluster
# 0             326.0     16125.763319    1887.108685
# 1             165.0     20212.026385     395.637635
# 2             323.0     13392.063357     871.505310
# 3             318.0     16184.207293    1921.303664
#
#          First Language Not English %  student_teacher_ratio  High Needs #.1  \
# cluster
# 0                                25.5                  11.90           73.30
# 1                                 3.7                   8.05           48.15
# 2                                48.3                  15.00           83.90
# 3                                19.5                   9.60           56.90
#
#          Economically Disadvantaged %  African American  Asian  Hispanic  \
# cluster
# 0                               67.80              21.8    3.7     58.60
# 1                               39.35               1.3    0.9      9.25
# 2                               74.60              15.2    0.6     36.20
# 3                               39.30              13.5    6.3     29.90
#
#          White  Native American  Native Hawaiian, Pacific Islander  \
# cluster
# 0        12.90             0.60                                0.3
# 1        83.75             0.65                                0.0
# 2        39.00             0.30                                0.3
# 3        43.70             0.00                                0.0
#
#          avg_salary_teachers  student_teacher_ratio
# cluster
# 0                    71511.0                  11.90
# 1                    61728.0                   8.05
# 2                    74180.0                  15.00
# 3                    77606.0                   9.60

# %% [markdown]
# ## 2.5 What type of features do low performing, low income schools have?

# %%
# filter dataframe to only low performing, low income
score_threshold = master_df['avg_score'].quantile(0.3)
income_threshold = master_df['Economically Disadvantaged %'].quantile(0.7)
filtered_df = master_df[(master_df['avg_score'] <= score_threshold) & (master_df['Economically Disadvantaged %'] >= income_threshold)]

cluster = kmeans_func(4, filtered_df)
cluster
# Out:
# 0    175
# 2    110
# 1     34
# 3     12
# Name: cluster, dtype: int64
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#           avg_score  pp_stloc_raw_MA  pp_fed_raw_MA  pp_total_raw_MA  \
# cluster
# 0        487.223000     14368.189235    1278.051384     15646.240619
# 1        486.240931     18510.375642    1175.495701     19685.871343
# 2        492.814470     15505.225894     768.942131     16274.168026
# 3        467.485417     31151.387372    2716.370128     33867.757500
#
#          ncesenroll  pp_stloc_raw_MA  pp_fed_raw_MA  \
# cluster
# 0        601.822857     14368.189235    1278.051384
# 1        670.441176     18510.375642    1175.495701
# 2        530.963636     15505.225894     768.942131
# 3         85.083333     31151.387372    2716.370128
#
#          First Language Not English %  student_teacher_ratio  High Needs #.1  \
# cluster
# 0                           49.062286              13.682286       83.647429
# 1                           42.697059              13.960187       75.658824
# 2                           19.468182              12.570000       63.573636
# 3                           28.016667               5.041667       97.650000
#
#          Economically Disadvantaged %  African American     Asian   Hispanic  \
# cluster
# 0                           69.187429         11.304000  5.595429  62.280571
# 1                           57.558824         50.500000  4.997059  26.088235
# 2                           50.173636          7.671818  3.051818  24.012727
# 3                           84.950000         16.341667  0.516667  54.333333
#
#              White  Native American  Native Hawaiian, Pacific Islander  \
# cluster
# 0        17.584571         0.167429                           0.021143
# 1        13.708824         0.326471                           0.155882
# 2        59.305455         0.300000                           0.111818
# 3        24.600000         0.091667                           0.000000
#
#          avg_salary_teachers  student_teacher_ratio
# cluster
# 0               76048.337143              13.682286
# 1              101063.676471              13.960187
# 2               75770.863636              12.570000
# 3               78886.500000               5.041667

# %% [markdown]
# ## 2.5 What type of features do low performing, high income schools have?

# %%
# filter dataframe to only low performing, low income
score_threshold = master_df['avg_score'].quantile(0.3)
income_threshold = master_df['Economically Disadvantaged %'].quantile(0.3)
filtered_df = master_df[(master_df['avg_score'] <= score_threshold) & (master_df['Economically Disadvantaged %'] <= income_threshold)]
filtered_df
# Out:
# 497.4333333333333
# 14.5
#     distname       schoolname  flag_nerds  flag_f33  ncesenroll gradespan  \
# 593  Lincoln  Hanscom Primary           0         0       305.0     PK-03
#
#      pp_stloc_raw_MA  pp_fed_raw_MA  pp_total_raw_MA  schoolstloc_raw_MA  ...  \
# 593     21924.322562     486.673367      22410.99593        6.884724e+06  ...
#
#      males_staff  fte_staff student_teacher_ratio nan_flag District Name  \
# 593          4.3       59.2                  10.3    False       Lincoln
#
#      District Code  salary_totals_teachers  avg_salary_teachers  FTE Count  \
# 593      1570000.0              10826154.0              90520.0      119.6
#
#      no_salary_flag
# 593           False
#
# [1 rows x 74 columns]
